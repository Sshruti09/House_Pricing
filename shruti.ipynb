# %% [markdown]
# <a href="https://colab.research.google.com/github/Sshruti09/House_Pricing/blob/main/shruti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ANALYSIS ON HOUSE PRICING**

# %% [markdown]
#  `MADE BY: Shruti Srivastava and Shalini Singh`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pro=pd.read_csv('dataset_testing.csv')

# %%
pro1=pd.read_csv('dataset_training.csv',index_col='Id')

# %%
pro1
# Out:
#       Unnamed: 0  MSSubClass  ...  SalePrice  TransformedPrice
# Id                            ...
# 1              0          60  ...     208500         12.247694
# 2              1          20  ...     181500         12.109011
# 3              2          60  ...     223500         12.317167
# 4              3          70  ...     140000         11.849398
# 5              4          60  ...     250000         12.429216
# ...          ...         ...  ...        ...               ...
# 1456        1455          60  ...     175000         12.072541
# 1457        1456          20  ...     210000         12.254863
# 1458        1457          70  ...     266500         12.493130
# 1459        1458          20  ...     142125         11.864462
# 1460        1459          20  ...     147500         11.901583
#
# [1460 rows x 81 columns]

# %%
pro=pd.read_csv('dataset_testing.csv')

# %%
pro
# Out:
#       Unnamed: 0    Id  MSSubClass  ...  YrSold  SaleType  SaleCondition
# 0              0  1461          20  ...    2010         2              0
# 1              1  1462          20  ...    2010         2              0
# 2              2  1463          60  ...    2010         2              0
# 3              3  1464          60  ...    2010         2              0
# 4              4  1465         120  ...    2010         2              0
# ...          ...   ...         ...  ...     ...       ...            ...
# 1454        1454  2915         160  ...    2006         2              0
# 1455        1455  2916         160  ...    2006         2              2
# 1456        1456  2917          20  ...    2006         2              2
# 1457        1457  2918          85  ...    2006         2              0
# 1458        1458  2919          60  ...    2006         2              0
#
# [1459 rows x 80 columns]

# %%
pd.read_csv('dataset_testing.csv',encoding='latin1')
# Out:
#       Unnamed: 0    Id  MSSubClass  ...  YrSold  SaleType  SaleCondition
# 0              0  1461          20  ...    2010         2              0
# 1              1  1462          20  ...    2010         2              0
# 2              2  1463          60  ...    2010         2              0
# 3              3  1464          60  ...    2010         2              0
# 4              4  1465         120  ...    2010         2              0
# ...          ...   ...         ...  ...     ...       ...            ...
# 1454        1454  2915         160  ...    2006         2              0
# 1455        1455  2916         160  ...    2006         2              2
# 1456        1456  2917          20  ...    2006         2              2
# 1457        1457  2918          85  ...    2006         2              0
# 1458        1458  2919          60  ...    2006         2              0
#
# [1459 rows x 80 columns]

# %%
pro.max()
# Out:
# Unnamed: 0        1458.0
# Id                2919.0
# MSSubClass         190.0
# MSZoning             4.0
# LotArea          56600.0
#                   ...
# MiscVal          17000.0
# MoSold              12.0
# YrSold            2010.0
# SaleType             8.0
# SaleCondition        5.0
# Length: 80, dtype: float64

# %%
pro.describe()
# Out:
#         Unnamed: 0           Id  ...     SaleType  SaleCondition
# count  1459.000000  1459.000000  ...  1459.000000    1459.000000
# mean    729.000000  2190.000000  ...     2.466073       0.342700
# std     421.321334   421.321334  ...     1.325872       0.914241
# min       0.000000  1461.000000  ...     0.000000       0.000000
# 25%     364.500000  1825.500000  ...     2.000000       0.000000
# 50%     729.000000  2190.000000  ...     2.000000       0.000000
# 75%    1093.500000  2554.500000  ...     2.000000       0.000000
# max    1458.000000  2919.000000  ...     8.000000       5.000000
#
# [8 rows x 80 columns]

# %% [markdown]
# # **PLOTTING OF AREA**

# %% [markdown]
# *The maximum area lotted is of 14000 sq. feat. this can be seen through the following graph*

# %%
pro1['LotArea'].head().plot.barh(hatch="oo", figsize=(12,5))

# %% [markdown]
# # **AREA HAVING MORE THAN 20k**

# %%
exp=[0.05,0.15,0.05,0.15,0.05]
la=pro1['LotArea']>=20000
la=pro1[la]
ce=la['LotArea'].head().value_counts().plot(kind='pie',explode=exp,subplots=True,legend=True)

# %%
ax=pro['HouseStyle'].head(10).plot.bar(figsize=(15,5),hatch="|+|")

# %% [markdown]
#  **The most common house styles are 0,1,4,6,8 and 9**

# %% [markdown]
# # **ON THE BASIS OF LANDCONTOUR**

# %%
gr=pro['LandContour'].value_counts()
ti=gr.head()
y=ti.plot(kind='pie',subplots=True,legend=True)

# %% [markdown]
# # **ANALYSIS ON THE BASIS OF YEAR BUILT**

# %%
gr=pro['YearBuilt'].value_counts()
ti=gr.head()
ti.plot(kind='pie')

# %% [markdown]
# ### *Hence maximum yearbuilt is in "2005"*

# %% [markdown]
# # **ANALYSIS ON THE BASIS OF WOODDESK**

# %%
H=pro['WoodDeckSF'].head(8).plot.barh(hatch='\\\\',figsize=(15,5),color='cyan')

# %% [markdown]
# # **COMPARISON BETWEEN YEARBUILT AND YEARREMOTE**

# %%
cols=['YearBuilt','YearRemodAdd']
M=pro[cols].plot.scatter(x='YearBuilt',y='YearRemodAdd',title='YearBuilt vs YearRemodAdd',figsize=(15,5))

# %% [markdown]
# # **COMPARISON BETWEEN OVERALLCONDITIONS AND OVERALLQUALIFICATIONS**

# %%
cols=['OverallCond','OverallQual']
pro[cols].head().plot.bar(x='OverallCond', y='OverallQual',title='OverallCond vs OverallQual')

# %%
cols=['BsmtFinSF1','BsmtUnfSF']

# %%
pro[cols].head() #subset
# Out:
#    BsmtFinSF1  BsmtUnfSF
# 0       468.0      270.0
# 1       923.0      406.0
# 2       791.0      137.0
# 3       602.0      324.0
# 4       263.0     1017.0

# %% [markdown]
# # *THE FOLLOWING GRAPH SHOWS THE DOWNFALL OF FINISHED BASEMENT AND THE RISING OF UNFINISHED BASEMENT* #

# %%
B=pro[cols].head().plot(figsize=(10,6))

# %%
O=sns.pairplot(pro[cols])

# %% [markdown]
# # **ANALYSIS ON THE BASIS OF SUBCLASS**

# %%
pro['MSSubClass'].value_counts().plot.bar(figsize=(15,5),hatch=".*.")
plt.show()

# %%
pro1['MSZoning'].value_counts().head(20).plot.barh(figsize=(15,5),hatch='.++.')
plt.show()

# %%
pro1['HouseStyle'].value_counts().head(5).plot.bar()

# %% [markdown]
# # **ANALYSIS ON THE BASIS OF BedroomAbvgr**

# %%
pro1['BedroomAbvGr'].value_counts().head(3).plot.pie()
plt.axis('equal')
plt.show()
